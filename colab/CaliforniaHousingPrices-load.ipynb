# %% [markdown]
# # Despliegue

# %% [markdown]
# ## Probar carga del modelo

# %%
import joblib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/UDENAR/Inteligencia Artificial/Sistemas Expertos/California Housing Prices/forestCalifornia.model"
model_forest_reg=joblib.load(path)

# %%
import pandas as pd

claves = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'ocean_proximity', 'bed_rooms_per_room']
valores = [-121.88, 37.46, 5.0, 1819.0, 245.0, 802.0, 228.0, 10.9722, '<1H OCEAN', 0.13468938977460143]

df = pd.DataFrame([valores], columns=claves)

print(df)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -121.88     37.46                 5.0       1819.0           245.0
#
#    population  households  median_income ocean_proximity  bed_rooms_per_room
# 0       802.0       228.0        10.9722       <1H OCEAN            0.134689

# %%
prediccion = model_forest_reg.predict(df)
print(str(prediccion[0]))
# Out:
# 488744.17082496977
